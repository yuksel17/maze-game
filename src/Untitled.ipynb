# %%
# %run demo.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/haunted-game/src/demo.py:1
# ----> 1 from haunted_problem import HauntedMazeProblem
#       2 from search4e import breadth_first_search
#       4 maze = [
#       5     ["#", "#", "#", "#", "#"],
#       6     ["#", ".", ".", ".", "#"],
#    (...)
#       9     ["#", "#", "#", "#", "#"]
#      10 ]
#
# File ~/Desktop/haunted-game/src/haunted_problem.py:1
# ----> 1 from search4e import Problem
#       3 WALL = "#"
#       4 FREE = "."
#
# ModuleNotFoundError: No module named 'search4e'
